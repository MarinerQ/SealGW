# %% [markdown]
# # Example3: Catalog test
#
# In this notebook I will show how to test seal's performance for a catalog.
#
# We will calculate 50% & 90% areas, search area, and make p-p plot.

# %%
import bilby
import numpy as np 
import time
import sys
import matplotlib.pyplot as plt
from multiprocessing import Pool
import multiprocessing
from functools import partial
from matplotlib.pyplot import MultipleLocator
from bilby.gw import conversion
from scipy.optimize import leastsq
import json
from pycbc.filter import matched_filter,matched_filter_core
from pycbc.types.timeseries import TimeSeries
from pycbc.types.frequencyseries import FrequencySeries
from lal import LIGOTimeGPS

import sealgw
from sealgw import seal
import sealgw.calculation as sealcal
import sealgw.simulation as sealsim
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1

# %%
# %%capture

seal_O2 = seal.Seal('example_outputs/sealconfig_O2_lhv_BNS.txt')

Nsample = 4
det_name_list = ['L1', 'H1', 'V1']
source_type = "BNS"
ncpu = 4
save_filename = 'example_outputs/catalog_statistics.txt' 
psd_files = ['example_inputs/L1_psd.txt','example_inputs/H1_psd.txt','example_inputs/V1_psd.txt']

catalog_stats = seal_O2.catalog_test(Nsample, det_name_list, source_type, ncpu, save_filename,duration = 320,
                      use_bilby_psd = False, custom_psd_path = psd_files)
# Out:
# 23:33 bilby INFO    : Waveform generator initiated with
#   frequency_domain_source_model: bilby.gw.source.lal_binary_neutron_star
#   time_domain_source_model: None
#   parameter_conversion: bilby.gw.conversion.convert_to_lal_binary_neutron_star_parameters
# 23:33 bilby INFO    : Injected signal in L1:
# 23:33 bilby INFO    :   optimal SNR = 1.67
# 23:33 bilby INFO    :   matched filter SNR = 1.73+1.20j
# 23:33 bilby INFO    :   chirp_mass = 1.1261122470886935
# 23:33 bilby INFO    : Injected signal in L1:
# 23:33 bilby INFO    :   mass_ratio = 0.9312932279058727
# 23:33 bilby INFO    :   optimal SNR = 8.23
# 23:33 bilby INFO    :   a_1 = 0.06627870186663427
# 23:33 bilby INFO    :   matched filter SNR = 7.93-0.76j
# 23:33 bilby INFO    :   a_2 = 0.07291012591606565
# 23:33 bilby INFO    :   chirp_mass = 1.0170911007999655
# 23:33 bilby INFO    : Injected signal in L1:
# 23:33 bilby INFO    : Injected signal in L1:
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   mass_ratio = 0.9595379395513511
# 23:33 bilby INFO    :   optimal SNR = 0.17
# 23:33 bilby INFO    :   optimal SNR = 0.95
# 23:33 bilby INFO    :   a_1 = 0.003181875973628512
# 23:33 bilby INFO    :   matched filter SNR = -0.51+0.61j
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   matched filter SNR = 0.26-0.40j
# 23:33 bilby INFO    :   a_2 = 0.05411430951736429
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   chirp_mass = 1.2758477204393093
# 23:33 bilby INFO    :   chirp_mass = 1.5725810703522591
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   mass_ratio = 0.9672023600665546
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   mass_ratio = 0.9581232606910365
# 23:33 bilby INFO    :   theta_jn = 1.2952397063489374
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   a_1 = 0.009550847428655841
# 23:33 bilby INFO    :   a_1 = 0.06666555263026197
# 23:33 bilby INFO    :   a_2 = 0.03187249574021259
# 23:33 bilby INFO    :   a_2 = 0.06192306878199588
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   psi = 1.6828227863778435
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   phase = 0.3724051708853215
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   theta_jn = 0.15997721585546382
# 23:33 bilby INFO    :   ra = 5.5795418044310985
# 23:33 bilby INFO    :   psi = 2.790820915241638
# 23:33 bilby INFO    :   dec = 1.060482020863177
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   luminosity_distance = 174.45010812132284
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   phase = 5.203546097422269
# 23:33 bilby INFO    :   theta_jn = 1.576405798673464
# 23:33 bilby INFO    :   theta_jn = 1.381181334045956
# 23:33 bilby INFO    :   geocent_time = 19227757.175256465
# 23:33 bilby INFO    :   ra = 4.462858217486579
# 23:33 bilby INFO    :   dec = -0.18231653558091712
# 23:33 bilby INFO    :   psi = 1.8710684144341214
# 23:33 bilby INFO    :   psi = 0.26493045514027413
# 23:33 bilby INFO    :   phase = 1.670609899671726
# 23:33 bilby INFO    :   luminosity_distance = 139.8238964470393
# 23:33 bilby INFO    :   phase = 3.2100263319813007
# 23:33 bilby INFO    :   geocent_time = 23321645.834018115
# 23:33 bilby INFO    :   ra = 2.0354468600544138
# 23:33 bilby INFO    :   ra = 0.4878649467159888
# 23:33 bilby INFO    :   dec = -0.7276015726534227
# 23:33 bilby INFO    :   dec = 1.1458653787579933
# 23:33 bilby INFO    :   luminosity_distance = 155.7724273891336
# 23:33 bilby INFO    :   luminosity_distance = 153.48161740416245
# 23:33 bilby INFO    :   geocent_time = 19328237.8537556
# 23:33 bilby INFO    :   geocent_time = 14464364.867066627
# 23:33 bilby INFO    : Injected signal in H1:
# 23:33 bilby INFO    :   optimal SNR = 2.00
# 23:33 bilby INFO    :   matched filter SNR = 1.23+0.60j
# 23:33 bilby INFO    :   chirp_mass = 1.1261122470886935
# 23:33 bilby INFO    :   mass_ratio = 0.9312932279058727
# 23:33 bilby INFO    :   a_1 = 0.06627870186663427
# 23:33 bilby INFO    : Injected signal in H1:
# 23:33 bilby INFO    :   a_2 = 0.07291012591606565
# 23:33 bilby INFO    :   optimal SNR = 4.29
# 23:33 bilby INFO    :   matched filter SNR = 3.00+0.35j
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   chirp_mass = 1.0170911007999655
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   mass_ratio = 0.9595379395513511
# 23:33 bilby INFO    : Injected signal in H1:
# 23:33 bilby INFO    : Injected signal in H1:
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   a_1 = 0.003181875973628512
# 23:33 bilby INFO    :   optimal SNR = 0.69
# 23:33 bilby INFO    :   theta_jn = 1.2952397063489374
# 23:33 bilby INFO    :   optimal SNR = 1.60
# 23:33 bilby INFO    :   a_2 = 0.05411430951736429
# 23:33 bilby INFO    :   matched filter SNR = 0.56+0.42j
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   psi = 1.6828227863778435
# 23:33 bilby INFO    :   matched filter SNR = -0.05-1.26j
# 23:33 bilby INFO    :   chirp_mass = 1.2758477204393093
# 23:33 bilby INFO    :   chirp_mass = 1.5725810703522591
# 23:33 bilby INFO    :   phase = 0.3724051708853215
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   mass_ratio = 0.9672023600665546
# 23:33 bilby INFO    :   ra = 5.5795418044310985
# 23:33 bilby INFO    :   mass_ratio = 0.9581232606910365
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   a_1 = 0.06666555263026197
# 23:33 bilby INFO    :   dec = 1.060482020863177
# 23:33 bilby INFO    :   a_1 = 0.009550847428655841
# 23:33 bilby INFO    :   theta_jn = 0.15997721585546382
# 23:33 bilby INFO    :   a_2 = 0.03187249574021259
# 23:33 bilby INFO    :   luminosity_distance = 174.45010812132284
# 23:33 bilby INFO    :   a_2 = 0.06192306878199588
# 23:33 bilby INFO    :   geocent_time = 19227757.175256465
# 23:33 bilby INFO    :   psi = 2.790820915241638
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   phase = 5.203546097422269
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   ra = 4.462858217486579
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   dec = -0.18231653558091712
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   luminosity_distance = 139.8238964470393
# 23:33 bilby INFO    :   theta_jn = 1.381181334045956
# 23:33 bilby INFO    :   theta_jn = 1.576405798673464
# 23:33 bilby INFO    :   psi = 1.8710684144341214
# 23:33 bilby INFO    :   psi = 0.26493045514027413
# 23:33 bilby INFO    :   geocent_time = 23321645.834018115
# 23:33 bilby INFO    :   phase = 1.670609899671726
# 23:33 bilby INFO    :   phase = 3.2100263319813007
# 23:33 bilby INFO    :   ra = 0.4878649467159888
# 23:33 bilby INFO    :   ra = 2.0354468600544138
# 23:33 bilby INFO    :   dec = -0.7276015726534227
# 23:33 bilby INFO    :   dec = 1.1458653787579933
# 23:33 bilby INFO    :   luminosity_distance = 155.7724273891336
# 23:33 bilby INFO    :   luminosity_distance = 153.48161740416245
# 23:33 bilby INFO    :   geocent_time = 19328237.8537556
# 23:33 bilby INFO    :   geocent_time = 14464364.867066627
# 23:33 bilby INFO    : Injected signal in V1:
# 23:33 bilby INFO    :   optimal SNR = 0.55
# 23:33 bilby INFO    :   matched filter SNR = 0.36+0.15j
# 23:33 bilby INFO    :   chirp_mass = 1.1261122470886935
# 23:33 bilby INFO    :   mass_ratio = 0.9312932279058727
# 23:33 bilby INFO    :   a_1 = 0.06627870186663427
# 23:33 bilby INFO    :   a_2 = 0.07291012591606565
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    : Injected signal in V1:
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   optimal SNR = 1.27
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   matched filter SNR = 1.47-0.19j
# 23:33 bilby INFO    :   theta_jn = 1.2952397063489374
# 23:33 bilby INFO    :   chirp_mass = 1.0170911007999655
# 23:33 bilby INFO    :   mass_ratio = 0.9595379395513511
# 23:33 bilby INFO    :   psi = 1.6828227863778435
# 23:33 bilby INFO    :   a_1 = 0.003181875973628512
# 23:33 bilby INFO    :   phase = 0.3724051708853215
# 23:33 bilby INFO    :   a_2 = 0.05411430951736429
# 23:33 bilby INFO    :   ra = 5.5795418044310985
# 23:33 bilby INFO    : Injected signal in V1:
# 23:33 bilby INFO    : Injected signal in V1:
# 23:33 bilby INFO    :   optimal SNR = 0.53
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   optimal SNR = 1.45
# 23:33 bilby INFO    :   dec = 1.060482020863177
# 23:33 bilby INFO    :   matched filter SNR = 1.57-0.85j
# 23:33 bilby INFO    :   luminosity_distance = 174.45010812132284
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   matched filter SNR = 2.40+0.20j
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   geocent_time = 19227757.175256465
# 23:33 bilby INFO    :   chirp_mass = 1.2758477204393093
# 23:33 bilby INFO    :   chirp_mass = 1.5725810703522591
# 23:33 bilby INFO    :   mass_ratio = 0.9581232606910365
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   mass_ratio = 0.9672023600665546
# 23:33 bilby INFO    :   theta_jn = 0.15997721585546382
# 23:33 bilby INFO    :   a_1 = 0.009550847428655841
# 23:33 bilby INFO    :   a_1 = 0.06666555263026197
# 23:33 bilby INFO    :   a_2 = 0.03187249574021259
# 23:33 bilby INFO    :   a_2 = 0.06192306878199588
# 23:33 bilby INFO    :   psi = 2.790820915241638
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   phase = 5.203546097422269
# 23:33 bilby INFO    :   tilt_1 = 0.0
# 23:33 bilby INFO    :   ra = 4.462858217486579
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   tilt_2 = 0.0
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   phi_12 = 0.0
# 23:33 bilby INFO    :   dec = -0.18231653558091712
# 23:33 bilby INFO    :   luminosity_distance = 139.8238964470393
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   phi_jl = 0.0
# 23:33 bilby INFO    :   geocent_time = 23321645.834018115
# 23:33 bilby INFO    :   theta_jn = 1.576405798673464
# 23:33 bilby INFO    :   theta_jn = 1.381181334045956
# 23:33 bilby INFO    :   psi = 0.26493045514027413
# 23:33 bilby INFO    :   psi = 1.8710684144341214
# 23:33 bilby INFO    :   phase = 1.670609899671726
# 23:33 bilby INFO    :   phase = 3.2100263319813007
# 23:33 bilby INFO    :   ra = 2.0354468600544138
# 23:33 bilby INFO    :   ra = 0.4878649467159888
# 23:33 bilby INFO    :   dec = 1.1458653787579933
# 23:33 bilby INFO    :   dec = -0.7276015726534227
# 23:33 bilby INFO    :   luminosity_distance = 153.48161740416245
# 23:33 bilby INFO    :   luminosity_distance = 155.7724273891336
# 23:33 bilby INFO    :   geocent_time = 19328237.8537556
# 23:33 bilby INFO    :   geocent_time = 14464364.867066627

# %%
catalog_stats
# Out:
# array([[9.12122866e+00, 4.79912041e+03, 2.28005397e+04, 1.42344202e+04,
#         7.83014531e-01, 2.42278671e+00],
#        [8.91849422e+00, 9.24332451e+03, 2.86642254e+04, 5.77350099e+03,
#         3.68360321e-01, 2.39280629e+00],
#        [9.21329196e+00, 2.68138583e+03, 2.03797939e+04, 1.40564900e+04,
#         8.26808240e-01, 2.40263772e+00],
#        [1.11497024e+01, 2.73124512e+02, 1.08083973e+03, 7.67166848e+01,
#         2.13066472e-01, 2.34963298e+00]])
